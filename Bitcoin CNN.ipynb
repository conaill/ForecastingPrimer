# %%
from numpy.random import seed
seed(314159)
import tensorflow as tf
tf.random.set_seed(160669)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import json
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/geral/Desktop/EOD_Bitcoin.csv") 
df.head(10)
# Out:
#   Transaction_Date            EOD_Timestamp  Record Count     price   quantity
# 0       2011-09-13  2011-09-13 19:34:36.000             1  5.970000   4.446800
# 1       2011-09-14  2011-09-14 15:42:31.000             1  5.530000   0.782450
# 2       2011-09-15  2011-09-15 15:11:22.000             1  5.130000   5.438650
# 3       2011-09-16  2011-09-16 16:13:02.000             1  4.850000   5.139461
# 4       2011-09-17  2011-09-17 15:32:08.000             1  4.870000   0.300000
# 5       2011-09-18  2011-09-18 20:11:23.000             1  4.920000  19.880000
# 6       2011-09-19  2011-09-19 13:47:03.000             1  4.900000  20.000000
# 7       2011-09-20  2011-09-20 16:38:45.000             1  5.660000   0.863000
# 8       2011-09-21  2011-09-21 16:47:28.000             3  5.712735   5.300000
# 9       2011-09-22  2011-09-22 13:32:57.000             1  5.720000  17.164000

# %%
# Pull out the Price along with Log transformation of Price and the Log Returns

df.drop(['EOD_Timestamp',  'Record Count',  'quantity'],  axis=1,  inplace=True) 

df = df.rename(columns = {"Transaction_Date":"timestamp", 
                          "price":"close"}) 

df['timestamp']  =  pd.to_datetime(df['timestamp'])
df  =  df.set_index(['timestamp'],  drop=True) 

df['log close']  = np.log(df['close'])
df['log return'] = np.log(df['close']).diff()

df = df[1:]

df.head(10)
# Out:
#                close  log close  log return
# timestamp
# 2011-09-14  5.530000   1.710188   -0.076559
# 2011-09-15  5.130000   1.635106   -0.075082
# 2011-09-16  4.850000   1.578979   -0.056127
# 2011-09-17  4.870000   1.583094    0.004115
# 2011-09-18  4.920000   1.593309    0.010215
# 2011-09-19  4.900000   1.589235   -0.004073
# 2011-09-20  5.660000   1.733424    0.144189
# 2011-09-21  5.712735   1.742698    0.009274
# 2011-09-22  5.720000   1.743969    0.001271
# 2011-09-23  5.720000   1.743969    0.000000

# %%
print("Start Date",df.index.min())
print("End Date",df.index.max())
# Out:
# Start Date 2011-09-14 00:00:00
# End Date 2019-11-06 00:00:00

# %%
# Plot Log prices

plt.figure(figsize=(10,  6)) 
plt.ylabel("Bitcoin Log Prices")
df['log close'].plot()

plt.figure(figsize=(10,  6)) 
plt.ylabel("Bitcoin Log Price Chinges")
df['log return'].plot()

# %%
# Descriptive Statistics for Log Prices

print("Log Prices\n")
print("Mean     ",df['log close'].mean())
print("Median   ",df['log close'].median())
print("Skewness ",df['log close'].skew())
print("Kurtosis ",df['log close'].kurt())

print("\nLog Price Differences\n")
print("Mean     ",df['log return'].mean())
print("Median   ",df['log return'].median())
print("Skewness ",df['log return'].skew())
print("Kurtosis ",df['log return'].kurt())
# Out:
# Log Prices
#
# Mean      6.101435555486407
# Median    6.238676125755892
# Skewness  -0.5232480788213172
# Kurtosis  -0.5725296114372869
#
# Log Price Differences
#
# Mean      0.002490337456614929
# Median    0.0020020026706728533
# Skewness  -1.2457321616430832
# Kurtosis  23.806023897715292

# %%
# Print Distribution of Log Prices

ax = df.hist(column='log close', bins=100, grid=False, figsize=(12,8), color='#86bf91', zorder=2, rwidth=0.9)

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

    # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Remove title
    x.set_title("")

    # Set x-axis label
    x.set_xlabel("Bitcoin Log Prices", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    x.set_ylabel("Count", labelpad=20, weight='bold', size=12)

# %%
# Print Distribution of Log Prices

ax = df.hist(column='log return', bins=100, grid=False, figsize=(12,8), color='#86bf91', zorder=2, rwidth=0.9)

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

    # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Remove title
    x.set_title("")

    # Set x-axis label
    x.set_xlabel("Bitcoin Log Price Differences", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    x.set_ylabel("Count", labelpad=20, weight='bold', size=12)

# %%
### Drop Close and LogDiff

df.drop(['close',  'log return'],  axis=1,  inplace=True) 
df.head(10)
# Out:
#             log close
# timestamp
# 2011-09-14   1.710188
# 2011-09-15   1.635106
# 2011-09-16   1.578979
# 2011-09-17   1.583094
# 2011-09-18   1.593309
# 2011-09-19   1.589235
# 2011-09-20   1.733424
# 2011-09-21   1.742698
# 2011-09-22   1.743969
# 2011-09-23   1.743969

# %%
### Split into Train and Test datasets

test_split  =  pd.Timestamp('2018-11-06') 
df  =  df['log close']
train_close = df.loc[:test_split] 
test_close = df.loc[test_split:] 
plt.figure(figsize=(10,  6))
axis = train_close.plot() 
test_close.plot(ax=axis) 
plt.legend(['train  close',  'test  close'])

# %%
print("Train Start Date:",train_close.index.min())
print("Train End Date:",train_close.index.max())
print("Train Observations:",len(train_close),"\n")
print("Test Start Date:",test_close.index.min())
print("Test End Date:",test_close.index.max())
print("Test Observations:",len(test_close))
# Out:
# Train Start Date: 2011-09-14 00:00:00
# Train End Date: 2018-11-06 00:00:00
# Train Observations: 2590
#
# Test Start Date: 2018-11-06 00:00:00
# Test End Date: 2019-11-06 00:00:00
# Test Observations: 366

# %%
from sklearn.preprocessing import MinMaxScaler

scaler  =  MinMaxScaler(feature_range=(-1,  1)) 
train_close_scaled = scaler.fit_transform(train_close.values.reshape(-1, 1)) 
test_close_scaled = scaler.transform(test_close.values.reshape(-1, 1))

# %%
import numpy as np

def split_data(dataset, steps): 
    X, Y = [], []
    for i in range(len(dataset)-steps): 
        x = dataset[i:i+steps] 
        X.append(x)
        y = dataset[i+steps] 
        Y.append(y)
    return np.array(X), np.array(Y)

# %%
n_steps = 30
train_X, train_Y = split_data(train_close_scaled, n_steps) 
test_X, test_Y = split_data(test_close_scaled, n_steps)

# %%
train_X = train_X.reshape(train_X.shape[0], train_X.shape[1], 1) 
test_X = test_X.reshape(test_X.shape[0], test_X.shape[1], 1)

# %%
from  keras.models  import  Sequential
from keras.layers import Dense, Conv1D
from keras.callbacks import EarlyStopping
from keras.layers import MaxPooling1D, Flatten

cnn = Sequential() 
cnn.add(Conv1D(filters=7,
        input_shape=(train_X.shape[1],  train_X.shape[2]), 
        activation='relu',
        kernel_size=3)) 
cnn.add(MaxPooling1D(pool_size=2)) 
cnn.add(Flatten()) 
cnn.add(Dense(units=1))
cnn.compile(loss='mean_squared_error',  optimizer='nadam')
# Out:
# Using TensorFlow backend.

# %%
cnn_history = cnn.fit(x=train_X,
                      y=train_Y, 
                      epochs=100, 
                      verbose=1)
# Out:
# Epoch 1/100
# 2560/2560 [==============================] - 0s 106us/step - loss: 0.0184
# Epoch 2/100
# 2560/2560 [==============================] - 0s 46us/step - loss: 7.8608e-04
# Epoch 3/100
# 2560/2560 [==============================] - 0s 43us/step - loss: 6.7882e-04
# Epoch 4/100
# 2560/2560 [==============================] - 0s 42us/step - loss: 6.2471e-04
# Epoch 5/100
# 2560/2560 [==============================] - 0s 44us/step - loss: 5.8532e-04
# Epoch 6/100
# 2560/2560 [==============================] - 0s 44us/step - loss: 5.8271e-04
# Epoch 7/100
# 2560/2560 [==============================] - ETA: 0s - loss: 5.6256e-0 - 0s 44us/step - loss: 5.5369e-04
# Epoch 8/100
# 2560/2560 [==============================] - 0s 46us/step - loss: 5.2876e-04
# Epoch 9/100
# 2560/2560 [==============================] - 0s 46us/step - loss: 5.0326e-04
# Epoch 10/100
# 2560/2560 [==============================] - 0s 44us/step - loss: 5.0184e-04
# Epoch 11/100
# 2560/2560 [==============================] - 0s 44us/step - loss: 4.9473e-04
# Epoch 12/100
# 2560/2560 [==============================] - 0s 42us/step - loss:
100
# 2560/2560 [==============================] - 0s 47us/step - loss: 2.7846e-04
# Epoch 72/100
# 2560/2560 [==============================] - 0s 51us/step - loss: 2.8282e-04
# Epoch 73/100
# 2560/2560 [==============================] - 0s 53us/step - loss: 2.6880e-04
# Epoch 74/100
# 2560/2560 [==============================] - 0s 50us/step - loss: 2.9543e-04
# Epoch 75/100
# 2560/2560 [==============================] - 0s 46us/step - loss: 2.8306e-04
# Epoch 76/100
# 2560/2560 [==============================] - 0s 46us/step - loss: 2.7153e-04
# Epoch 77/100
# 2560/2560 [==============================] - 0s 49us/step - loss: 2.7139e-04
# Epoch 78/100
# 2560/2560 [==============================] - 0s 47us/step - loss: 2.8040e-04
# Epoch 79/100
# 2560/2560 [==============================] - 0s 48us/step - loss: 2.5472e-04
# Epoch 80/100
# 2560/2560 [==============================] - 0s 49us/step - loss: 2.9193e-04
# Epoch 81/100
# 2560/2560 [==============================] - 0s 51us/step - loss: 2.7192e-04
# Epoch 82/100
# 2560/2560 [==============================] - 0s 51us/step - loss: 2.7129e-04
# Epoch 83/100
# 2560/2560 [==============================] - 0s 49us/step - loss: 2.5879e-04
# Epoch 84/100
# 2560/2560 [==============================] - 0s 51us/step - loss: 2.8334e-04
# Epoch 85/100
# 2560/2560 [==============================] - 0s 52us/step - loss: 2.6162e-04
# Epoch 86/100
# 2560/2560 [==============================] - 0s 50us/step - loss: 2.5611e-04
# Epoch 87/100
# 2560/2560 [==============================] - 0s 48us/step - loss: 2.7139e-04
# Epoch 88/100
# 2560/2560 [==============================] - 0s 49us/step - loss: 2.5378e-04
# Epoch 89/100
# 2560/2560 [==============================] - 0s 48us/step - loss: 2.7947e-04
# Epoch 90/100
# 2560/2560 [==============================] - 0s 54us/step - loss: 2.4941e-04
# Epoch 91/100
# 2560/2560 [==============================] - 0s 49us/step - loss: 2.6989e-04
# Epoch 92/100
# 2560/2560 [==============================] - 0s 45us/step - loss: 2.4767e-04: 0s - loss: 2.5420e-
# Epoch 93/100
# 2560/2560 [==============================] - 0s 43us/step - loss: 2.4397e-04
# Epoch 94/100
# 2560/2560 [==============================] - 0s 43us/step - loss: 2.4706e-04
# Epoch 95/100
# 2560/2560 [==============================] - 0s 45us/step - loss: 2.6071e-04
# Epoch 96/100
# 2560/2560 [==============================] - 0s 44us/step - loss: 2.4681e-04: 0s - loss: 2.1478e-
# Epoch 97/100
# 2560/2560 [==============================] - 0s 44us/step - loss: 2.4903e-04
# Epoch 98/100
# 2560/2560 [==============================] - 0s 43us/step - loss: 2.3056e-04
# Epoch 99/100
# 2560/2560 [==============================] - 0s 47us/step - loss: 2.7679e-04
# Epoch 100/100
# 2560/2560 [==============================] - 0s 46us/step - loss: 2.3763e-04

# %%
from sklearn.metrics import r2_score

y_train_pred_cnn = cnn.predict(train_X) 
y_pred_test_cnn = cnn.predict(test_X)

print("The R2 score on the Train set is:\t{:0.3f}".format(r2_score(train_Y,y_train_pred_cnn)))
print("The R2 score on the Test set is:\t{:0.3f}".format(r2_score(test_Y,y_pred_test_cnn)))
# Out:
# The R2 score on the Train set is:	0.999
# The R2 score on the Test set is:	0.987

# %%
### Calculate RMSE

trainRMSE =  np.sqrt(((y_train_pred_cnn - train_Y) ** 2).mean())
print("The RMSE on the Train set is:\t{:0.5f}".format(trainRMSE))

testRMSE =  np.sqrt(((y_pred_test_cnn - test_Y) ** 2).mean())
print("The RMSE on the Test set is:\t{:0.5f}".format(testRMSE))
# Out:
# The RMSE on the Train set is:	0.01523
# The RMSE on the Test set is:	0.01133

# %%
cnn_test  =  cnn.evaluate(test_X,  test_Y,  batch_size=1) 
print("CNN: {}".format(cnn_test))
# Out:
# 336/336 [==============================] - 0s 439us/step
# CNN: 0.00012842922270619344

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(20,  12)) 
plt.plot(test_Y,  label='Actual') 
plt.plot(y_pred_test_cnn,  label='CNN') 
plt.title("CNN's  Prediction") 
plt.ylabel('Bitcoin  Close  Daily  scaled') 
plt.legend()
plt.show()
